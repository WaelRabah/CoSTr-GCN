# %% [markdown]
# ### Install modules

# %%
# change the cuda version if your GPU is compatible with newer versions
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install pytorch_lightning
# !pip install torchmetrics
# !pip install continual-inference
# !pip install matplotlib

# %% [markdown]
# ### Imports

# %%
# from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import LightningLoggerBase
from pytorch_lightning.loggers.logger import rank_zero_experiment
from pytorch_lightning.utilities import rank_zero_only
 
import torch
from datetime import datetime
from model import CoSTrGCN
import os
import matplotlib.pyplot as plt
import collections
from data_loaders.data_loader import load_data_sets
import pytorch_lightning as pl
from train import train_model

# %% [markdown]
# ### Training

# %%
train_model()
# Out:
# 100%|██████████| 108/108 [00:21<00:00,  4.98it/s]
# 503
# Number of gestures per class in the original training set :
# Class NO GESTURE has 57 samples
# Class RIGHT has 24 samples
# Class KNOB has 24 samples
# Class CROSS has 24 samples
# Class THREE has 24 samples
# Class V has 24 samples
# Class ONE has 24 samples
# Class FOUR has 24 samples
# Class GRAB has 25 samples
# Class DENY has 24 samples
# Class MENU has 24 samples
# Class CIRCLE has 24 samples
# Class TAP has 23 samples
# Class PINCH has 23 samples
# Class LEFT has 24 samples
# Class TWO has 24 samples
# Class OK has 24 samples
# Class EXPAND has 24 samples
# training
# Number of gestures per class in the training set after augmentation:
# Class NO GESTURE has 56 samples
# Class RIGHT has 24 samples
# Class KNOB has 24 samples
# Class CROSS has 24 samples
# Class THREE has 24 samples
# Class V has 24 samples
# Class ONE has 24 samples
# Class FOUR has 24 samples
# Class GRAB has 25 samples
# Class DENY has 24 samples
# Class MENU has 24 samples
# Class CIRCLE has 24 samples
# Class TAP has 23 samples
# Class PINCH has 23 samples
# Class LEFT has 24 samples
# Class TWO has 24 samples
# Class OK has 24 samples
# Class EXPAND has 24 samples
# 100%|██████████| 72/72 [00:13<00:00,  5.36it/s]
# 328
# Number of gestures per class in the original test set :
# Class NO GESTURE has 29 samples
# Class RIGHT has 16 samples
# Class KNOB has 16 samples
# Class CROSS has 18 samples
# Class THREE has 16 samples
# Class V has 15 samples
# Class ONE has 16 samples
# Class FOUR has 16 samples
# Class GRAB has 16 samples
# Class DENY has 16 samples
# Class MENU has 16 samples
# Class CIRCLE has 16 samples
# Class TAP has 14 samples
# Class PINCH has 16 samples
# Class LEFT has 16 samples
# Class TWO has 16 samples
# Class OK has 15 samples
# Class EXPAND has 15 samples
# test
# test data num:  297
#
# init model.............
# C:\Users\WR11\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\utilities\warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# C:\Users\WR11\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\utilities\warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.LightningLoggerBase` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.Logger` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)
# C:\Users\WR11\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\trainer\connectors\accelerator_connector.py:446: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type                    | Params
# -------------------------------------------------------------
# 0 | loss             | CrossEntropyLoss        | 0
# 1 | train_acc        | Accuracy                | 0
# 2 | valid_acc        | Accuracy                | 0
# 3 | test_acc         | Accuracy                | 0
# 4 | confusion_matrix | ConfusionMatrix         | 0
# 5 | gcn              | SGCN                    | 163 K
# 6 | encoder          | TransformerGraphEncoder | 1.6 M
# 7 | out              | Sequential              | 19.1 K
# -------------------------------------------------------------
# 1.8 M     Trainable params
# 0         Non-trainable params
# 1.8 M     Total params
# 3.539     Total estimated model params size (MB)
# d_model (the number of expected features in the encoder inputs/outputs):128
# Number of heads :8
# dropout rate :0.3
# Learning rate 0.001
# Sanity Checking: 0it [00:00, ?it/s]
# c:\Users\WR11\Desktop\codebases\CoSTr-GCN\layers\continual_transformer_layers.py:385: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_weights=F.softmax((Q @ K.transpose(-2,-1))/sqrt_dk)
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# C:\Users\WR11\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\trainer\trainer.py:653: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\WR11\Desktop\codebases\CoSTr-GCN\training_notebook.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/WR11/Desktop/codebases/CoSTr-GCN/training_notebook.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> train_model()
#
# File c:\Users\WR11\Desktop\codebases\CoSTr-GCN\train.py:198, in train_model(dataset_name)
#     195 plot_history(history.history, "CoSTrGCN")
#     197 # plot_confusion_matrix(confusion_matrix,labels,'Confusion_matrices/confusion_matrix_{}.eps'.format(dataset_name))
# --> 198 model = CoSTrGCN.load_from_checkpoint(checkpoint_path=checkpoint_callback.best_model_path, adjacency_matrix=adjacency_matrix,
#     199                                       optimizer_params=optimizer_params, labels=labels, d_model=128, n_heads=8, num_classes=num_classes, dropout=dropout_rate)
#     200 test_metrics = trainer.test(model, dataloaders=test_loader)
#     202 print(test_metrics)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\core\saving.py:137, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      57 @classmethod
#      58 def load_from_checkpoint(
#      59     cls,
#    (...)
#      64     **kwargs,
#      65 ):
#      66     r"""
#      67     Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint
#      68     it stores the arguments passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    (...)
#     135         y_hat = pretrained_model(x)
#     136     """
# --> 137     return _load_from_checkpoint(
#     138         cls,
#     139         checkpoint_path,
#     140         map_location,
#     141         hparams_file,
#     142         strict,
#     143         **kwargs,
#     144     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\core\saving.py:184, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     182     map_location = lambda storage, loc: storage
#     183 with pl_legacy_patch():
# --> 184     checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     186 if hparams_file is not None:
#     187     extension = hparams_file.split(".")[-1]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pytorch_lightning\utilities\cloud_io.py:46, in load(path_or_url, map_location)
#      44     return torch.hub.load_state_dict_from_url(str(path_or_url), map_location=map_location)
#      45 fs = get_filesystem(path_or_url)
# ---> 46 with fs.open(path_or_url, "rb") as f:
#      47     return torch.load(f, map_location=map_location)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\fsspec\spec.py:1034, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1032 else:
#    1033     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1034     f = self._open(
#    1035         path,
#    1036         mode=mode,
#    1037         block_size=block_size,
#    1038         autocommit=ac,
#    1039         cache_options=cache_options,
#    1040         **kwargs,
#    1041     )
#    1042     if compression is not None:
#    1043         from fsspec.compression import compr
#
# File ~\AppData\Roaming\Python\Python38\site-packages\fsspec\implementations\local.py:162, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     160 if self.auto_mkdir and "w" in mode:
#     161     self.makedirs(self._parent(path), exist_ok=True)
# --> 162 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\fsspec\implementations\local.py:260, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     258 self.compression = get_compression(path, compression)
#     259 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 260 self._open()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\fsspec\implementations\local.py:265, in LocalFileOpener._open(self)
#     263 if self.f is None or self.f.closed:
#     264     if self.autocommit or "w" not in self.mode:
# --> 265         self.f = open(self.path, mode=self.mode)
#     266         if self.compression:
#     267             compress = compr[self.compression]
#
# PermissionError: [Errno 13] Permission denied: 'c:/Users/WR11/Desktop/codebases/CoSTr-GCN'
